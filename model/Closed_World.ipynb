# %% [markdown]
# ## Closed world

# %% [markdown]
# ### 1. RandomForest

# %%
from google.colab import drive
import pickle
import numpy as np

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 데이터 로드

with open("./drive/MyDrive/data/processed_mon_data_closed_world.pkl", "rb") as f:
    data = pickle.load(f)
X = np.column_stack(list(data['features'].values()))
y = np.array(data['y'])  # 라벨은 그대로 사용

# %%
# 데이터 분할

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# 모델 학습 - Random Forest

from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(max_depth=20, n_estimators=100, random_state=42, class_weight='balanced')
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20, random_state=42)

# %%
# 모델 평가

from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
y_pred = model_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.64
# Precision: 0.64
# Recall: 0.64
#               precision    recall  f1-score   support
#
#            0       0.58      0.45      0.51        40
#            1       0.47      0.40      0.43        40
#            2       0.69      0.88      0.77        40
#            3       0.62      0.70      0.66        40
#            4       0.57      0.60      0.59        40
#            5       0.72      0.57      0.64        40
#            6       0.83      0.75      0.79        40
#            7       0.69      0.72      0.71        40
#            8       0.68      0.75      0.71        40
#            9       0.61      0.62      0.62        40
#           10       0.65      0.50      0.56        40
#           11       0.61      0.50      0.55        40
#           12       0.86      0.80      0.83        40
#           13       0.56      0.45      0.50        40
#           14       0.54      0.47      0.51        40
#           15       0.72      0.78      0.75        40
#           16       0.75      0.53      0.62        40
#           17       0.50      0.55      0.52        40
#           18       0.71      0.62      0.67        40
#           19       0.57      0.68      0.62        40
#           20       0.89      0.97      0.93        40
#           21       0.33      0.25      0.29        40
#           22       0.51      0.57      0.54        40
#           23       0.79      0.85      0.82        40
#           24       0.50      0.38      0.43        40
#           25       0.63      0.65      0.64        40
#           26       0.67      0.78      0.72        40
#           27       0.63      0.47      0.54        40
#           28       0.73      0.75      0.74        40
#           29       0.64      0.62      0.63        40
#           30       0.67      0.88      0.76        40
#           31       0.67      0.75      0.71        40
#           32       0.55      0.55      0.55        40
#           33       0.62      0.65      0.63        40
#           34       0.29      0.15      0.20        40
#           35       0.67      0.70      0.68        40
#           36       0.61      0.68      0.64        40
#           37       0.64      0.45      0.53        40
#           38       0.53      0.78      0.63        40
#           39       0.66      0.72      0.69        40
#           40       0.58      0.62      0.60        40
#           41       0.68      0.75      0.71        40
#           42       0.40      0.40      0.40        40
#           43       0.74      0.85      0.79        40
#           44       0.84      0.90      0.87        40
#           45       0.37      0.42      0.40        40
#           46       0.65      0.60      0.62        40
#           47       0.56      0.50      0.53        40
#           48       0.59      0.55      0.57        40
#           49       0.69      0.72      0.71        40
#           50       0.57      0.57      0.57        40
#           51       0.46      0.47      0.47        40
#           52       0.72      0.78      0.75        40
#           53       0.62      0.60      0.61        40
#           54       0.76      0.78      0.77        40
#           55       0.62      0.50      0.56        40
#           56       0.80      0.82      0.81        40
#           57       0.65      0.65      0.65        40
#           58       0.69      0.88      0.77        40
#           59       0.74      0.78      0.76        40
#           60       0.70      0.78      0.74        40
#           61       0.61      0.47      0.54        40
#           62       0.63      0.68      0.65        40
#           63       0.68      0.47      0.56        40
#           64       0.45      0.55      0.49        40
#           65       0.74      0.62      0.68        40
#           66       0.60      0.68      0.64        40
#           67       0.70      0.70      0.70        40
#           68       0.65      0.42      0.52        40
#           69       0.57      0.57      0.57        40
#           70       0.97      0.95      0.96        40
#           71       0.43      0.40      0.42        40
#           72       0.57      0.60      0.59        40
#           73       0.78      0.88      0.82        40
#           74       0.37      0.38      0.37        40
#           75       0.78      0.88      0.82        40
#           76       0.88      0.90      0.89        40
#           77       0.54      0.33      0.41        40
#           78       0.48      0.38      0.42        40
#           79       0.49      0.60      0.54        40
#           80       0.83      0.72      0.77        40
#           81       0.61      0.62      0.62        40
#           82       0.60      0.45      0.51        40
#           83       0.71      0.85      0.77        40
#           84       0.57      0.60      0.59        40
#           85       0.62      0.75      0.68        40
#           86       0.85      0.97      0.91        40
#           87       0.75      0.82      0.79        40
#           88       0.61      0.62      0.62        40
#           89       0.40      0.42      0.41        40
#           90       0.81      0.75      0.78        40
#           91       0.69      0.82      0.75        40
#           92       0.70      0.57      0.63        40
#           93       0.77      0.93      0.84        40
#           94       0.35      0.45      0.40        40
#
#     accuracy                           0.64      3800
#    macro avg       0.64      0.64      0.63      3800
# weighted avg       0.64      0.64      0.63      3800

# %% [markdown]
# ### 2. Support Vector Machine

# %%
# 모델 학습 - SVM

from sklearn.svm import SVC
model_svm = SVC(kernel='rbf', C=200, gamma=0.5, random_state=42, class_weight='balanced')
model_svm.fit(X_train, y_train)
# Out:
# SVC(C=200, class_weight='balanced', gamma=0.5, random_state=42)

# %%
# 모델 평가

y_pred = model_svm.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Confusion Matrix:")
print(conf_matrix)

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.27
# Precision: 0.25
# Recall: 0.27
# Confusion Matrix:
# [[ 1  0  1 ...  0  2  6]
#  [ 0  0  3 ...  0  0  0]
#  [ 0  0 21 ...  0  2  0]
#  ...
#  [ 0  0  2 ...  0  0  5]
#  [ 0  0  0 ...  0 32  0]
#  [ 0  0  0 ...  0  0 14]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.03      0.05        40
#            1       0.00      0.00      0.00        40
#            2       0.19      0.53      0.27        40
#            3       0.67      0.35      0.46        40
#            4       0.27      0.07      0.12        40
#            5       0.11      0.07      0.09        40
#            6       0.19      0.35      0.25        40
#            7       0.25      0.20      0.22        40
#            8       0.60      0.07      0.13        40
#            9       0.29      0.23      0.25        40
#           10       0.09      0.03      0.04        40
#           11       0.15      0.35      0.21        40
#           12       0.57      0.60      0.59        40
#           13       0.00      0.00      0.00        40
#           14       0.60      0.07      0.13        40
#           15       0.39      0.30      0.34        40
#           16       0.90      0.47      0.62        40
#           17       0.17      0.03      0.04        40
#           18       0.30      0.23      0.26        40
#           19       0.00      0.00      0.00        40
#           20       0.64      0.75      0.69        40
#           21       0.10      0.15      0.12        40
#           22       0.00      0.00      0.00        40
#           23       0.18      0.12      0.15        40
#           24       0.00      0.00      0.00        40
#           25       0.00      0.00      0.00        40
#           26       0.33      0.12      0.18        40
#           27       0.00      0.00      0.00        40
#           28       0.67      0.05      0.09        40
#           29       0.18      0.42      0.26        40
#           30       0.56      0.75      0.64        40
#           31       0.25      0.17      0.21        40
#           32       0.62      0.25      0.36        40
#           33       0.38      0.40      0.39        40
#           34       0.20      0.23      0.21        40
#           35       0.11      0.28      0.15        40
#           36       0.26      0.33      0.29        40
#           37       0.00      0.00      0.00        40
#           38       0.24      0.53      0.33        40
#           39       0.23      0.23      0.23        40
#           40       0.00      0.00      0.00        40
#           41       0.28      0.62      0.38        40
#           42       0.22      0.05      0.08        40
#           43       0.38      0.45      0.41        40
#           44       0.48      0.85      0.61        40
#           45       0.10      0.15      0.12        40
#           46       0.00      0.00      0.00        40
#           47       0.12      0.20      0.15        40
#           48       0.16      0.12      0.14        40
#           49       0.33      0.70      0.45        40
#           50       0.25      0.40      0.31        40
#           51       0.00      0.00      0.00        40
#           52       0.00      0.00      0.00        40
#           53       0.25      0.07      0.12        40
#           54       0.00      0.00      0.00        40
#           55       0.33      0.07      0.12        40
#           56       0.07      0.03      0.04        40
#           57       0.29      0.05      0.09        40
#           58       0.27      0.68      0.38        40
#           59       0.18      0.47      0.27        40
#           60       0.23      0.25      0.24        40
#           61       0.20      0.20      0.20        40
#           62       0.43      0.25      0.32        40
#           63       0.00      0.00      0.00        40
#           64       0.24      0.38      0.29        40
#           65       0.22      0.55      0.31        40
#           66       0.28      0.95      0.43        40
#           67       0.41      0.38      0.39        40
#           68       0.00      0.00      0.00        40
#           69       0.47      0.35      0.40        40
#           70       0.50      1.00      0.67        40
#           71       0.00      0.00      0.00        40
#           72       0.42      0.28      0.33        40
#           73       0.29      0.95      0.44        40
#           74       0.19      0.28      0.22        40
#           75       0.23      0.85      0.37        40
#           76       0.78      0.70      0.74        40
#           77       0.00      0.00      0.00        40
#           78       0.11      0.15      0.13        40
#           79       0.05      0.07      0.06        40
#           80       0.27      0.60      0.38        40
#           81       0.00      0.00      0.00        40
#           82       0.44      0.35      0.39        40
#           83       0.11      0.07      0.09        40
#           84       0.35      0.42      0.39        40
#           85       0.38      0.75      0.51        40
#           86       0.61      0.82      0.70        40
#           87       0.00      0.00      0.00        40
#           88       0.00      0.00      0.00        40
#           89       0.38      0.30      0.33        40
#           90       0.61      0.28      0.38        40
#           91       0.12      0.05      0.07        40
#           92       0.00      0.00      0.00        40
#           93       0.30      0.80      0.43        40
#           94       0.09      0.35      0.14        40
#
#     accuracy                           0.27      3800
#    macro avg       0.25      0.27      0.22      3800
# weighted avg       0.25      0.27      0.22      3800
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
