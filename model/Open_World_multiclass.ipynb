# %% [markdown]
# ## Open world - MultiClass

# %% [markdown]
# ### 1. RandomForest

# %%
from google.colab import drive
import pickle
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 로드:
with open("./drive/MyDrive/data/processed_multiclass_data_open_world.pkl", "rb") as f:
    data = pickle.load(f)
X = np.column_stack(list(data['features'].values()))
y = np.array(data['y'])

# %%
# 데이터 분할

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# 모델 학습 - Random Forest

from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_rf, X_train, y_train, cv=5)
print("Cross-validation scores:", scores)
print("Mean cross-validation score:", scores.mean())
# Out:
# Cross-validation scores: [0.61647727 0.60710227 0.61107955 0.61420455 0.61534091]
# Mean cross-validation score: 0.6128409090909092

# %%
# 모델 평가

from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
y_pred = model_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.62
# Precision: 0.62
# Recall: 0.62
#               precision    recall  f1-score   support
#
#         -1.0       0.59      0.61      0.60       600
#          0.0       0.71      0.55      0.62        40
#          1.0       0.45      0.45      0.45        40
#          2.0       0.68      0.80      0.74        40
#          3.0       0.58      0.55      0.56        40
#          4.0       0.63      0.65      0.64        40
#          5.0       0.63      0.65      0.64        40
#          6.0       0.73      0.80      0.76        40
#          7.0       0.51      0.55      0.53        40
#          8.0       0.82      0.70      0.76        40
#          9.0       0.71      0.55      0.62        40
#         10.0       0.46      0.42      0.44        40
#         11.0       0.67      0.60      0.63        40
#         12.0       0.75      0.82      0.79        40
#         13.0       0.61      0.35      0.44        40
#         14.0       0.43      0.33      0.37        40
#         15.0       0.67      0.70      0.68        40
#         16.0       0.71      0.62      0.67        40
#         17.0       0.38      0.38      0.38        40
#         18.0       0.69      0.68      0.68        40
#         19.0       0.59      0.57      0.58        40
#         20.0       0.83      1.00      0.91        40
#         21.0       0.41      0.33      0.36        40
#         22.0       0.43      0.40      0.42        40
#         23.0       0.73      0.75      0.74        40
#         24.0       0.27      0.23      0.25        40
#         25.0       0.52      0.55      0.54        40
#         26.0       0.62      0.75      0.68        40
#         27.0       0.59      0.50      0.54        40
#         28.0       0.76      0.78      0.77        40
#         29.0       0.48      0.50      0.49        40
#         30.0       0.70      0.75      0.72        40
#         31.0       0.51      0.60      0.55        40
#         32.0       0.65      0.38      0.48        40
#         33.0       0.63      0.68      0.65        40
#         34.0       0.34      0.28      0.31        40
#         35.0       0.69      0.78      0.73        40
#         36.0       0.74      0.70      0.72        40
#         37.0       0.42      0.40      0.41        40
#         38.0       0.67      0.78      0.72        40
#         39.0       0.70      0.65      0.68        40
#         40.0       0.53      0.60      0.56        40
#         41.0       0.74      0.88      0.80        40
#         42.0       0.50      0.53      0.51        40
#         43.0       0.89      0.85      0.87        40
#         44.0       0.83      0.95      0.88        40
#         45.0       0.36      0.40      0.38        40
#         46.0       0.73      0.40      0.52        40
#         47.0       0.47      0.55      0.51        40
#         48.0       0.65      0.60      0.62        40
#         49.0       0.66      0.78      0.71        40
#         50.0       0.59      0.72      0.65        40
#         51.0       0.29      0.30      0.30        40
#         52.0       0.78      0.70      0.74        40
#         53.0       0.53      0.57      0.55        40
#         54.0       0.82      0.78      0.79        40
#         55.0       0.38      0.38      0.38        40
#         56.0       0.82      0.90      0.86        40
#         57.0       0.78      0.72      0.75        40
#         58.0       0.82      0.90      0.86        40
#         59.0       0.70      0.75      0.72        40
#         60.0       0.80      0.70      0.75        40
#         61.0       0.53      0.57      0.55        40
#         62.0       0.64      0.62      0.63        40
#         63.0       0.68      0.42      0.52        40
#         64.0       0.47      0.45      0.46        40
#         65.0       0.66      0.57      0.61        40
#         66.0       0.48      0.72      0.58        40
#         67.0       0.82      0.80      0.81        40
#         68.0       0.50      0.40      0.44        40
#         69.0       0.40      0.50      0.44        40
#         70.0       0.85      0.97      0.91        40
#         71.0       0.57      0.57      0.57        40
#         72.0       0.68      0.75      0.71        40
#         73.0       0.64      0.80      0.71        40
#         74.0       0.35      0.33      0.34        40
#         75.0       0.82      0.80      0.81        40
#         76.0       0.93      0.93      0.93        40
#         77.0       0.39      0.28      0.32        40
#         78.0       0.53      0.42      0.47        40
#         79.0       0.47      0.47      0.47        40
#         80.0       0.87      0.85      0.86        40
#         81.0       0.67      0.75      0.71        40
#         82.0       0.81      0.53      0.64        40
#         83.0       0.64      0.70      0.67        40
#         84.0       0.62      0.60      0.61        40
#         85.0       0.52      0.65      0.58        40
#         86.0       0.78      1.00      0.88        40
#         87.0       0.78      0.72      0.75        40
#         88.0       0.60      0.62      0.61        40
#         89.0       0.47      0.38      0.42        40
#         90.0       0.63      0.60      0.62        40
#         91.0       0.61      0.62      0.62        40
#         92.0       0.65      0.55      0.59        40
#         93.0       0.73      0.93      0.81        40
#         94.0       0.44      0.45      0.44        40
#
#     accuracy                           0.62      4400
#    macro avg       0.62      0.62      0.62      4400
# weighted avg       0.62      0.62      0.61      4400

# %% [markdown]
# ### 2. Support Vector Machine

# %%
# 모델 학습 - SVM

from sklearn.svm import SVC
model_svm = SVC(kernel='rbf', C=10, gamma=0.5, random_state=42)
model_svm.fit(X_train, y_train)
# Out:
# SVC(C=10, gamma=0.5, random_state=42)

# %%
# 모델 평가
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

y_pred = model_svm.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Confusion Matrix:")
print(conf_matrix)

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.15
# Precision: 0.03
# Recall: 0.15
# Confusion Matrix:
# [[583   0   0 ...   0   0   0]
#  [ 40   0   0 ...   0   0   0]
#  [ 40   0   0 ...   0   0   0]
#  ...
#  [ 27   0   0 ...   0   0   0]
#  [ 40   0   0 ...   0   0   0]
#  [ 31   0   0 ...   0   0   0]]
#               precision    recall  f1-score   support
#
#         -1.0       0.14      0.97      0.24       600
#          0.0       0.00      0.00      0.00        40
#          1.0       0.00      0.00      0.00        40
#          2.0       0.00      0.00      0.00        40
#          3.0       0.00      0.00      0.00        40
#          4.0       0.00      0.00      0.00        40
#          5.0       0.00      0.00      0.00        40
#          6.0       0.42      0.20      0.27        40
#          7.0       0.00      0.00      0.00        40
#          8.0       0.00      0.00      0.00        40
#          9.0       0.00      0.00      0.00        40
#         10.0       0.00      0.00      0.00        40
#         11.0       0.00      0.00      0.00        40
#         12.0       0.00      0.00      0.00        40
#         13.0       0.00      0.00      0.00        40
